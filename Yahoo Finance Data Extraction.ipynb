# %%
import pandas as pd
import yfinance as yf
from yahoofinancials import YahooFinancials

# %%
tsla_df = yf.download('TSLA', 
                      start='2019-01-01', 
                      end='2019-12-31', 
                      progress=False)
tsla_df.head()
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2018-12-31  67.557999  67.842003  65.052002  66.559998  66.559998  31511500
# 2019-01-02  61.220001  63.026001  59.759998  62.023998  62.023998  58293000
# 2019-01-03  61.400002  61.880001  59.476002  60.071999  60.071999  34826000
# 2019-01-04  61.200001  63.599998  60.546001  63.537998  63.537998  36970500
# 2019-01-07  64.344002  67.348000  63.549999  66.991997  66.991997  37756000

# %%
tsla_df = yf.download('TSLA')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
tsla_df.head()
# Out:
#              Open   High    Low  Close  Adj Close    Volume
# Date
# 2010-06-29  3.800  5.000  3.508  4.778      4.778  93831500
# 2010-06-30  5.158  6.084  4.660  4.766      4.766  85935500
# 2010-07-01  5.000  5.184  4.054  4.392      4.392  41094000
# 2010-07-02  4.600  4.620  3.742  3.840      3.840  25699000
# 2010-07-06  4.000  4.000  3.166  3.222      3.222  34334500

# %%
tsla_df.shape
# Out:
# (2696, 6)

# %% [markdown]
# ### Aside from the yf.download function, we can use the Ticker() module. Below I present a short example of downloading the entire history of Tesla’s stock prices:

# %%
ticker = yf.Ticker('TSLA')

tsla_df = ticker.history(period="max")

tsla_df['Close'].plot(title="TSLA's stock price")
# Out:
# <AxesSubplot:title={'center':"TSLA's stock price"}, xlabel='Date'>

# %% [markdown]
# ### The second library I wanted to mention in this article is yahoofinancials. While I find it a bit more demanding to work with this library, it provides a lot of information that is not available in yfinance. Let’s start with downloading Tesla’s historical stock prices:

# %%
yahoo_financials = YahooFinancials('TSLA')

data = yahoo_financials.get_historical_price_data(start_date='2000-01-01', 
                                                  end_date='2019-12-31', 
                                                  time_interval='weekly')

tsla_df = pd.DataFrame(data['TSLA']['prices'])
tsla_df = tsla_df.drop('date', axis=1).set_index('formatted_date')
tsla_df.head()
# Out:
#                  high    low   open  close     volume  adjclose
# formatted_date
# 2010-06-28      6.084  3.508  3.800  3.840  246560000     3.840
# 2010-07-05      4.000  2.996  4.000  3.480  127753000     3.480
# 2010-07-12      4.300  3.380  3.590  4.128   77194500     4.128
# 2010-07-19      4.450  3.900  4.274  4.258   35878500     4.258
# 2010-07-26      4.300  3.910  4.300  3.988   15260000     3.988

# %% [markdown]
# ### Using NSEtool library

# %%
from nsetools import Nse

# %%
nse =Nse()

# %%
print(nse)
# Out:
# Driver Class for National Stock Exchange (NSE)

# %%
q =nse.get_quote('infy')

# %%
type(q)
# Out:
# dict

# %%
from pprint import pprint
pprint(q)
# Out:
# {'adhocMargin': None,
#  'applicableMargin': 16.91,
#  'averagePrice': 1391.19,
#  'basePrice': 1373.6,
#  'bcEndDate': None,
#  'bcStartDate': None,
#  'buyPrice1': None,
#  'buyPrice2': None,
#  'buyPrice3': None,
#  'buyPrice4': None,
#  'buyPrice5': None,
#  'buyQuantity1': None,
#  'buyQuantity2': None,
#  'buyQuantity3': None,
#  'buyQuantity4': None,
#  'buyQuantity5': None,
#  'change': 11.0,
#  'closePrice': 0.0,
#  'cm_adj_high_dt': '16-MAR-21',
#  'cm_adj_low_dt': '19-MAR-20',
#  'cm_ffm': 512881.56,
#  'companyName': 'Infosys Limited',
#  'css_status_desc': 'Listed',
#  'dayHigh': 1406.0,
#  'dayLow': 1380.5,
#  'deliveryQuantity': 5151968.0,
#  'deliveryToTradedQuantity': 55.08,
#  'exDate': '23-OCT-20',
#  'extremeLossMargin': 3.5,
#  'faceValue': 5.0,
#  'high52': 1406.0,
#  'indexVar': None,
#  'isExDateFlag': False,
#  'isinCode': 'INE009A01021',
#  'lastPrice': 1384.6,
#  'low52': 509.25,
#  'marketType': 'N',
#  'ndEndDate': None,
#  'ndStartDate': None,
# ...

# %%
 nse.get_index_list()
# Out:
# ['NIFTY 50 Pre Open',
#  'NIFTY 50',
#  'NIFTY NEXT 50',
#  'NIFTY100 LIQ 15',
#  'NIFTY BANK',
#  'INDIA VIX',
#  'NIFTY 100',
#  'NIFTY 500',
#  'NIFTY MIDCAP 100',
#  'NIFTY MIDCAP 50',
#  'NIFTY INFRA',
#  'NIFTY REALTY',
#  'NIFTY ENERGY',
#  'NIFTY FMCG',
#  'NIFTY MNC',
#  'NIFTY PHARMA',
#  'NIFTY PSE',
#  'NIFTY PSU BANK',
#  'NIFTY SERV SECTOR',
#  'NIFTY IT',
#  'NIFTY SMLCAP 100',
#  'NIFTY 200',
#  'NIFTY AUTO',
#  'NIFTY MEDIA',
#  'NIFTY METAL',
#  'NIFTY DIV OPPS 50',
#  'NIFTY COMMODITIES',
#  'NIFTY CONSUMPTION',
#  'NIFTY CPSE',
#  'NIFTY FIN SERVICE',
#  'NIFTY GROWSECT 15',
#  'NIFTY50 VALUE 20',
#  'NIFTY50 TR 2X LEV',
#  'NIFTY50 PR 2X LEV',
#  'NIFTY50 TR 1X INV',
#  'NIFTY50 PR 1X INV',
#  'NIFTY ALPHA 50',
#  'NIFTY50 EQL WGT',
#  'NIFTY100 EQL WGT',
#  'NIFTY100 LOWVOL30',
#  'NIFTY MID LIQ 15',
#  'NIFTY PVT BANK',
#  'NIFTY100 QUALTY30',
#  'NIFTY GS 8 13YR',
#  'NIFTY GS 10YR',
#  'NIFTY GS 10YR CLN',
#  'NIFTY GS 4 8YR',
#  'NIFTY GS 11 15YR',
# ...

# %%
nse.get_index_quote("nifty bank") # code can be provided in upper|lower case.
# Out:
# {'name': 'NIFTY BANK',
#  'lastPrice': 34804.6,
#  'change': '-377.95',
#  'pChange': '-1.07',
#  'imgFileName': 'NIFTY_BANK_open.png'}

# %%
all_stock_codes = nse.get_stock_codes()
pprint(all_stock_codes)
# Out:
# {'20MICRONS': '20 Microns Limited',
#  '21STCENMGM': '21st Century Management Services Limited',
#  '3IINFOTECH': '3i Infotech Limited',
#  '3MINDIA': '3M India Limited',
#  '3PLAND': '3P Land Holdings Limited',
#  '5PAISA': '5Paisa Capital Limited',
#  '63MOONS': '63 moons technologies limited',
#  'A2ZINFRA': 'A2Z Infra Engineering Limited',
#  'AAKASH': 'Aakash Exploration Services Limited',
#  'AARON': 'Aaron Industries Limited',
#  'AARTIDRUGS': 'Aarti Drugs Limited',
#  'AARTIIND': 'Aarti Industries Limited',
#  'AARTISURF': 'Aarti Surfactants Limited',
#  'AARVEEDEN': 'Aarvee Denims & Exports Limited',
#  'AARVI': 'Aarvi Encon Limited',
#  'AAVAS': 'Aavas Financiers Limited',
#  'ABAN': 'Aban Offshore Limited',
#  'ABB': 'ABB India Limited',
#  'ABBOTINDIA': 'Abbott India Limited',
#  'ABCAPITAL': 'Aditya Birla Capital Limited',
#  'ABFRL': 'Aditya Birla Fashion and Retail Limited',
#  'ABMINTLTD': 'ABM International Limited',
#  'ACC': 'ACC Limited',
# ...

# %%
type(all_stock_codes)
# Out:
# dict

# %%
all_stock_codes.items()
# Out:
# dict_items([('SYMBOL', 'NAME OF COMPANY'), ('20MICRONS', '20 Microns Limited'), ('21STCENMGM', '21st Century Management Services Limited'), ('3IINFOTECH', '3i Infotech Limited'), ('3MINDIA', '3M India Limited'), ('3PLAND', '3P Land Holdings Limited'), ('5PAISA', '5Paisa Capital Limited'), ('63MOONS', '63 moons technologies limited'), ('A2ZINFRA', 'A2Z Infra Engineering Limited'), ('AAKASH', 'Aakash Exploration Services Limited'), ('AARON', 'Aaron Industries Limited'), ('AARTIDRUGS', 'Aarti Drugs Limited'), ('AARTIIND', 'Aarti Industries Limited'), ('AARTISURF', 'Aarti Surfactants Limited'), ('AARVEEDEN', 'Aarvee Denims & Exports Limited'), ('AARVI', 'Aarvi Encon Limited'), ('AAVAS', 'Aavas Financiers Limited'), ('ABAN', 'Aban Offshore Limited'), ('ABB', 'ABB India Limited'), ('ABBOTINDIA', 'Abbott India Limited'), ('ABCAPITAL', 'Aditya Birla Capital Limited'), ('ABFRL', 'Aditya Birla Fashion and Retail Limited'), ('ABMINTLTD', 'ABM International Limited'), ('ACC', 'ACC Limited'), ('A
# ...

# %%
# Extracting key-value of dictionary in variables 
key, val = next(iter(all_stock_codes.items()))

# %%
comp_name = list(all_stock_codes.keys())

# %%
comp_name
# Out:
# ['20MICRONS',
#  '21STCENMGM',
#  '3IINFOTECH',
#  '3MINDIA',
#  '3PLAND',
#  '5PAISA',
#  '63MOONS',
#  'A2ZINFRA',
#  'AAKASH',
#  'AARON',
#  'AARTIDRUGS',
#  'AARTIIND',
#  'AARTISURF',
#  'AARVEEDEN',
#  'AARVI',
#  'AAVAS',
#  'ABAN',
#  'ABB',
#  'ABBOTINDIA',
#  'ABCAPITAL',
#  'ABFRL',
#  'ABMINTLTD',
#  'ACC',
#  'ACCELYA',
#  'ACCURACY',
#  'ACE',
#  'ACRYSIL',
#  'ADANIENT',
#  'ADANIGREEN',
#  'ADANIPORTS',
#  'ADANIPOWER',
#  'ADANITRANS',
#  'ADFFOODS',
#  'ADHUNIKIND',
#  'ADL',
#  'ADORWELD',
#  'ADROITINFO',
#  'ADSL',
#  'ADVANIHOTR',
#  'ADVENZYMES',
#  'AEGISCHEM',
#  'AFFLE',
#  'AGARIND',
#  'AGCNET',
#  'AGRITECH',
#  'AGROPHOS',
#  'AHLADA',
#  'AHLEAST',
#  'AHLUCONT',
#  'AHLWEST',
#  'AIAENG',
#  'AIRAN',
#  'AJANTPHARM',
#  'AJMERA',
#  'AKASH',
#  'AKG',
#  'AKSHARCHEM',
#  'AKSHOPTFBR',
#  'AKZOINDIA',
#  'ALANKIT',
#  'ALBERTDAVD',
#  'ALEMBICLTD',
#  'ALICON',
#  'ALKALI',
#  'ALKEM',
#  'ALKYLAMINE',
#  'ALLCARGO',
#  'ALLSEC',
#  'ALMONDZ',
# ...

# %%
# Delete the symbol item from the list
comp_name.pop(0)
# Out:
# 'SYMBOL'

# %%
comp1 = ['20MICRONS',
 '21STCENMGM',
 '3IINFOTECH',]

# %%
comp_name.remove('AIAENG')

# %%
import pandas as pd
nifty50 =pd.read_csv('ind_niftynext50list.csv')

# %%
nifty50
# Out:
#                                     Company Name                  Industry  \
# 0                                       ACC Ltd.  CEMENT & CEMENT PRODUCTS
# 1                              Abbott India Ltd.                    PHARMA
# 2                        Adani Green Energy Ltd.                     POWER
# 3                        Adani Transmission Ltd.                     POWER
# 4                        Alkem Laboratories Ltd.                    PHARMA
# 5                            Ambuja Cements Ltd.  CEMENT & CEMENT PRODUCTS
# 6                          Aurobindo Pharma Ltd.                    PHARMA
# 7                         Avenue Supermarts Ltd.            CONSUMER GOODS
# 8               Bajaj Holdings & Investment Ltd.        FINANCIAL SERVICES
# 9                              Bandhan Bank Ltd.        FINANCIAL SERVICES
# 10                                Bank of Baroda        FINANCIAL SERVICES
# ...

# %%
nifty=[]
nifty = nifty50['Symbol']

# %%
type(nifty)
# Out:
# pandas.core.series.Series

# %%
a=str('that's')
# Out:
#   File "<ipython-input-102-5bc29e849c0c>", line 1
#     a=str('that's')
#                 ^
# SyntaxError: invalid syntax

# %%
nifty
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-3d1bb5359f56> in <module>
# ----> 1 nifty
#
# NameError: name 'nifty' is not defined

# %%
import time
import datetime
import pandas as pd

ticker  = nifty
period1 = int(time.mktime(datetime.datetime(2014,12,1,23,59).timetuple()))
period2 = int(time.mktime(datetime.datetime(2020,12,31,23,59).timetuple()))
interval = '1wk' #1d, 1m
df1=pd.DataFrame()
df2=pd.DataFrame()
for tick in ticker:
    query_string = f'https://query1.finance.yahoo.com/v7/finance/download/{tick}.NS?period1={period1}&period2={period2}&interval={interval}&events=history&includeAdjustedClose=true'
    
    print(query_string)
    df1 = pd.DataFrame(pd.read_csv(query_string))
    df2['Date']= df1['Date']
    df2[tick]= df1['Close']
    
    

#df1 = pd.read_csv(df)
df2.head(20)
df2.to_csv('df_test.csv', index=False)
# Out:
# https://query1.finance.yahoo.com/v7/finance/download/ACC.NS?period1=1417458540&period2=1609439340&interval=1wk&events=history&includeAdjustedClose=true
# https://query1.finance.yahoo.com/v7/finance/download/ABBOTINDIA.NS?period1=1417458540&period2=1609439340&interval=1wk&events=history&includeAdjustedClose=true
# https://query1.finance.yahoo.com/v7/finance/download/ADANIGREEN.NS?period1=1417458540&period2=1609439340&interval=1wk&events=history&includeAdjustedClose=true
# https://query1.finance.yahoo.com/v7/finance/download/ADANITRANS.NS?period1=1417458540&period2=1609439340&interval=1wk&events=history&includeAdjustedClose=true
# https://query1.finance.yahoo.com/v7/finance/download/ALKEM.NS?period1=1417458540&period2=1609439340&interval=1wk&events=history&includeAdjustedClose=true
# https://query1.finance.yahoo.com/v7/finance/download/AMBUJACEM.NS?period1=1417458540&period2=1609439340&interval=1wk&events=history&includeAdjustedClose=true
# ...

# %%
df1.to_csv('df_test.csv')

# %%
# Creating a data set with one day data
import time
import datetime
import pandas as pd

ticker  = nifty
period1 = int(time.mktime(datetime.datetime(2021,3,16,23,59).timetuple()))
period2 = int(time.mktime(datetime.datetime(2021,3,16,23,59).timetuple()))
interval = '1d'#'1wk' #1d, 1m
df1=pd.DataFrame()
df2=pd.DataFrame()
for tick in ticker:
    query_string = f'https://query1.finance.yahoo.com/v7/finance/download/{tick}.NS?period1={period1}&period2={period2}&interval={interval}&events=history&includeAdjustedClose=true'
    
    #print(query_string)
    df1 = pd.DataFrame(pd.read_csv(query_string))
    df1['Symbol']= tick
    df2=df2.append(df1, ignore_index=True)
    '''
    df2['Date']= df1['Date']
    df2['Symbol'] = tick
    df2['Open']= df1['Open']
    df2['High']= df1['High']
    df2['Low']= df1['Low']
    df2['Close']= df1['Close']
    df2['Adj Close']= df1['Adj Close']
    df2['Volume']= df1['Volume']
    '''
    
    

#df1 = pd.read_csv(df)
df2.head(20)
#df2.to_csv('df_test.csv', index=False)
# Out:
#           Date          Open          High           Low         Close  \
# 0   2021-03-16   1771.099976   1789.750000   1760.900024   1766.150024
# 1   2021-03-16  14530.000000  14800.000000  14300.000000  14771.799805
# 2   2021-03-16   1209.900024   1244.400024   1206.300049   1219.800049
# 3   2021-03-16    782.299988    792.799988    762.000000    780.299988
# 4   2021-03-16   2686.000000   2702.300049   2645.949951   2657.500000
# 5   2021-03-16    284.899994    290.000000    284.250000    285.549988
# 6   2021-03-16    836.000000    852.849976    828.299988    840.950012
# 7   2021-03-16   3117.000000   3166.000000   3050.000000   3071.000000
# 8   2021-03-16   3500.050049   3588.000000   3480.699951   3502.850098
# 9   2021-03-16    343.750000    345.000000    334.500000    339.500000
# 10  2021-03-16     79.500000     79.949997     76.400002     78.849998
# 11  2021-03-16    719.000000    735.950012    719.000000    727.549988
# ...

# %%
df2.to_csv('df_test1.csv', index=False)

# %%
import pandas as pd
 
cols = ['Zip']
lst = []
zip = 32100
 
for a in range(10):
    lst.append([zip])
    zip = zip + 1
 
df = pd.DataFrame(lst, columns=cols)
 
print(df)
# Out:
#      Zip
# 0  32100
# 1  32101
# 2  32102
# 3  32103
# 4  32104
# 5  32105
# 6  32106
# 7  32107
# 8  32108
# 9  32109
